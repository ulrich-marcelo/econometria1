# %% [markdown]
# Ejercicio 1: python as a calculator

# %%
print(1+1)
print(5*(4-1)**2)
# Out:
# 45

# %% [markdown]
# Ejercicio 1.4

# %%
a = [1,2]
del a[1]
a
# Out:
# [1]

# %% [markdown]
# El resto desde la guía se entienden, al pedo copiarlos
